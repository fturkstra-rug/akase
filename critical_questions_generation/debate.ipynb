# %% [markdown]
# ## Prepare debate

# %%
import boto3
import json
from botocore.config import Config
import tqdm

# %%
config = Config(read_timeout=200)
session = boto3.Session(profile_name="default")
client = boto3.client("bedrock-agent-runtime", region_name="us-west-2", config=config)
FLOW_IDENTIFIER = "RSO7CQDJCL"

# %%
def invoke_flow(flowAliasIdentifier, context):
    try:
        response = client.invoke_flow(
            flowIdentifier=FLOW_IDENTIFIER,
            flowAliasIdentifier=flowAliasIdentifier, 
            inputs=[
                {
                    "content": {"document": context},
                    "nodeName": "FlowInputNode",
                    "nodeOutputName": "document"
                }
            ]
        )
        for event in response.get('responseStream'):
            if 'flowOutputEvent' in event:
                if event['flowOutputEvent']['nodeName'] == 'Flow':
                    return event['flowOutputEvent']['content']['document']
        else:
            return False
        
    except Exception as e:
        print(f"An error occured when invoking flow with Alias ID {flowAliasIdentifier}: {e}")
        return False

# %% [markdown]
# ## Run debate

# %%
test_questions_file = "test.json"

with open(test_questions_file, 'r') as f:
    data = json.load(f)

for entry in tqdm.tqdm(data.values(), desc="Processing interventions"):

    intervention = entry["intervention"]
    intervention_id = entry["intervention_id"]
    questions = entry["cqs"]

    # Prepare debate
    debate = {}
    output_file = f"debates/debate_{intervention_id}.json"

    # Load debate data
    questions = '\n'.join([f"{i+1}. {q["cq"]}" for i, q in enumerate(questions)])
    
    debate["intervention"] = intervention
    debate["questions"] = questions

    # Opening statements
    opening_statement_1 = invoke_flow('JFFQRXHJY0', str(debate))
    debate["opening_statement_1"] = opening_statement_1
    opening_statement_2 = invoke_flow('JFFQRXHJY0', str(debate))
    debate["opening_statement_2"] = opening_statement_2

    # Rebuttals
    rebuttal_1 = invoke_flow('3LGFTPJQF3', str(debate))
    debate["rebuttal_1"] = rebuttal_1
    rebuttal_2 = invoke_flow('3LGFTPJQF3', str(debate))
    debate["rebuttal_2"] = rebuttal_2

    # Closing statements
    closing_statement_1 = invoke_flow('QAQCBAD9NE', str(debate))
    debate["closing_statement_1"] = closing_statement_1
    closing_statement_2 = invoke_flow('QAQCBAD9NE', str(debate))
    debate["closing_statement_2"] = closing_statement_2

    # Judge's decision
    verdict = invoke_flow('E57ITLRQST', (str(debate)))
    debate["verdict"] = verdict

    # Save debate to JSON
    with open(output_file, "w") as f:
        json.dump(debate, f, indent=4)

    print(f"Saved debate to: {output_file}")
# Out:
# Processing interventions:   3%|▎         | 1/34 [01:41<55:48, 101.46s/it]
# Saved debate to: debates/debate_CLINTON_27.json
# Processing interventions:   6%|▌         | 2/34 [03:21<53:45, 100.81s/it]
# Saved debate to: debates/debate_CLINTON_277.json
# Processing interventions:   9%|▉         | 3/34 [04:41<47:05, 91.16s/it]
# Saved debate to: debates/debate_CLINTON_47.json
# Processing interventions:  12%|█▏        | 4/34 [06:26<48:22, 96.77s/it]
# Saved debate to: debates/debate_Feedback-Commenter_183.json
# Processing interventions:  15%|█▍        | 5/34 [07:52<44:45, 92.59s/it]
# Saved debate to: debates/debate_HOLT_122.json
# Processing interventions:  18%|█▊        | 6/34 [09:46<46:39, 99.97s/it]
# Saved debate to: debates/debate_HOLT_159.json
# Processing interventions:  21%|██        | 7/34 [11:23<44:34, 99.06s/it]
# Saved debate to: debates/debate_AB_68.json
# Processing interventions:  24%|██▎       | 8/34 [13:17<44:59, 103.84s/it]
# Saved debate to: debates/debate_Antanagoge_218.json
# Processing interventions:  26%|██▋       | 9/34 [15:03<43:33, 104.55s/it]
# Saved debate to: debates/debate_CLINTON_105.json
# Processing interventions:  29%|██▉       | 10/34 [17:01<43:29, 108.74s/it]
# Saved debate to: debates/debate_CLINTON_116.json
# Processing interventions:  32%|███▏      | 11/34 [18:55<42:13, 110.13s/it]
# Saved debate to: debates/debate_CLINTON_118.json
# Processing interventions:  35%|███▌      | 12/34 [20:55<41:30, 113.20s/it]
# Saved debate to: debates/debate_CLINTON_172.json
# Processing interventions:  38%|███▊      | 13/34 [22:49<39:40, 113.36s/it]
# Saved debate to: debates/debate_MT_53.json
# Processing interventions:  41%|████      | 14/34 [24:23<35:53, 107.69s/it]
# Saved debate to: debates/debate_NMmom_209.json
# Processing interventions:  44%|████▍     | 15/34 [25:49<32:01, 101.12s/it]
# Saved debate to: debates/debate_REBacon_165.json
# Processing interventions:  47%|████▋     | 16/34 [27:20<29:27, 98.17s/it]
# Saved debate to: debates/debate_howie_230.json
# Processing interventions:  50%|█████     | 17/34 [29:12<28:57, 102.22s/it]
# Saved debate to: debates/debate_jccjoin_151.json
# Processing interventions:  53%|█████▎    | 18/34 [30:45<26:33, 99.59s/it]
# Saved debate to: debates/debate_martinezcs_20.json
# Processing interventions:  56%|█████▌    | 19/34 [32:16<24:14, 96.99s/it]
# Saved debate to: debates/debate_pnorton_210.json
# Processing interventions:  59%|█████▉    | 20/34 [34:06<23:29, 100.71s/it]
# Saved debate to: debates/debate_radamchak_175.json
# Processing interventions:  62%|██████▏   | 21/34 [35:41<21:27, 99.03s/it]
# Saved debate to: debates/debate_stone_170.json
# Processing interventions:  65%|██████▍   | 22/34 [37:37<20:49, 104.16s/it]
# Saved debate to: debates/debate_wkemp_142.json
# Processing interventions:  68%|██████▊   | 23/34 [39:14<18:41, 101.91s/it]
# Saved debate to: debates/debate_TRUMP_153.json
# Processing interventions:  71%|███████   | 24/34 [40:34<15:54, 95.42s/it]
# Saved debate to: debates/debate_TRUMP_160.json
# Processing interventions:  74%|███████▎  | 25/34 [42:26<15:03, 100.34s/it]
# Saved debate to: debates/debate_TRUMP_185.json
# Processing interventions:  76%|███████▋  | 26/34 [44:11<13:34, 101.79s/it]
# Saved debate to: debates/debate_TRUMP_208.json
# Processing interventions:  79%|███████▉  | 27/34 [45:29<11:03, 94.78s/it]
# Saved debate to: debates/debate_TRUMP_214.json
# Processing interventions:  82%|████████▏ | 28/34 [47:02<09:25, 94.21s/it]
# Saved debate to: debates/debate_TRUMP_218.json
# Processing interventions:  85%|████████▌ | 29/34 [48:48<08:07, 97.53s/it]
# Saved debate to: debates/debate_CLINTON_136.json
# Processing interventions:  88%|████████▊ | 30/34 [50:22<06:26, 96.60s/it]
# Saved debate to: debates/debate_TRUMP_15.json
# Processing interventions:  91%|█████████ | 31/34 [51:56<04:47, 95.83s/it]
# Saved debate to: debates/debate_ND_19.json
# Processing interventions:  94%|█████████▍| 32/34 [53:27<03:08, 94.35s/it]
# Saved debate to: debates/debate_CF_58.json
# Processing interventions:  97%|█████████▋| 33/34 [54:58<01:33, 93.26s/it]
# Saved debate to: debates/debate_JL_69.json
# Processing interventions: 100%|██████████| 34/34 [56:36<00:00, 99.89s/it]
# Saved debate to: debates/debate_MP_24.json
